# %% [markdown]
# # markdown introduction

# %% [markdown]
# # heading1
# ## heading2
# ### heading3
# #### heading4
# ##### heading5
# ###### heading6

# %% [markdown]
# **bold**

# %% [markdown]
# *italic*<br/>
# <strike>strikiking text</strike><br/>
# `highligting text`

# %% [markdown]
# <img src="data:image/png;base64,..." width="100px" height="100px">

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# %%HTML
# <iframe width="853" height="480" src="https://www.youtube.com/embed/hEgO047GxaQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
# Out:
# <iframe width="853" height="480" src="https://www.youtube.com/embed/hEgO047GxaQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>

# %% [markdown]
# * python
# * java
# * R programming
# * scripting languages
#  - html
#  - xml

# %% [markdown]
# # python programming

# %% [markdown]
# ## Python introduction

# %%
print("hello world!")
print("apssdc")
# Out:
# hello world!
# apssdc

# %%
print(1)
# Out:
# 1

# %% [markdown]
# # operators

# %% [markdown]
# * arithematic operators
# * relational operators
# * assignment operators
# * logical operators
# * bitwise operators
# * identity operators
# * membership operators

# %% [markdown]
# ### Arithematic operators

# %%
print(29 + 939)
print(100 - 80)
print(10 * 20)
print(10 / 3)
# Out:
# 968
# 20
# 200
# 3.3333333333333335

# %%
type(1)
# Out:
# int

# %%
type(10 / 3)
# Out:
# float

# %%
10 // 3
# Out:
# 3

# %%
10 % 3
# Out:
# 1

# %%
2 ** 4
# Out:
# 16

# %%
pow(2,4)
# Out:
# 16

# %% [markdown]
# ### Logical operators

# %%
True and True
# Out:
# True

# %%
False and False
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or True
# Out:
# True

# %%
False or False
# Out:
# False

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %% [markdown]
# ### relational operators

# %%
2 == 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 < 10
# Out:
# True

# %%
10 > 20
# Out:
# False

# %% [markdown]
# ### assignment operators

# %%
a = 10

# %%
type(a)
# Out:
# int

# %%
a="hello"
type(a)
# Out:
# str

# %%
type(a)
# Out:
# str

# %%
a=b=c=10

# %%
a
b
c
# Out:
# 3

# %%
a,b,c=1,2,3

# %%
print(a,b,c)
# Out:
# 1 2 3

# %%
a,b=b,a

# %%
a,b
# Out:
# (2, 1)

# %%
a=1
a
# Out:
# 1

# %%
a++ # it is not supported in python
# Out:
#   File "<ipython-input-42-16a96addd613>", line 1
#     a++ #it is not supported in python
#                                       ^
# SyntaxError: invalid syntax

# %%
a = a + 1
a
# Out:
# 2

# %%
a += 1
a
# Out:
# 3

# %%
a *= 10
a
# Out:
# 30

# %%
a //= 3
a
# Out:
# 3

# %% [markdown]
# ### Bitwise operators

# %%
4 & 7
# Out:
# 4

# %% [markdown]
# 4 - 1 0 0
# 7 - 1 1 1
# & - 1 0 0

# %%
7 | 4
# Out:
# 7

# %%
8 << 2
# Out:
# 32

# %%
8 >> 2
# Out:
# 2

# %% [markdown]
# ### Identity operators

# %%
2 == 3
# Out:
# False

# %%
2 is 3
# Out:
# False

# %%
2 != 3
# Out:
# True

# %%
2 is not 3
# Out:
# True

# %% [markdown]
# ### Membership operators

# %%
"ap" in "apssdc"
# Out:
# True

# %%
"Ap" in "apssdc"
# Out:
# False

# %%
'a' in "apssdc"
# Out:
# True

# %%
"t" not in "apssdc"
# Out:
# True

# %% [markdown]
# <iframe width="853" height="480" src="https://www.youtube.com/embed/hEgO047GxaQ" frameborder="0" allow="accelerometer; autoplay; encrypted-media; gyroscope; picture-in-picture" allowfullscreen></iframe>
